# %%
from sqlalchemy import create_engine
from sqlalchemy import Table,String,Integer,ForeignKey, Column, MetaData,String,CHAR,Integer
from sqlalchemy import inspect
from sqlalchemy.sql import text

# %%
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# %%
Base = declarative_base()

# %%
engine = create_engine("sqlite:///database.db",echo = False)

# %%
Base.metadata.create_all(bind=engine)

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.to_sql('users', con = engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21288\1720768667.py in <module>
# ----> 1 df.to_sql('users', con = engine)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2985         from pandas.io import sql
#    2986
# -> 2987         return sql.to_sql(
#    2988             self,
#    2989             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693         )
#     694
# --> 695     return pandas_sql.to_sql(
#     696         frame,
#     697         name,
#
# ...

# %%
with engine.connect() as conn:
    conn.execute(text(" SELECT * FROM users")).fetchall()

# %%
with engine.begin() as connection:
    df.to_sql('users', con = connection, if_exists = "append")

# %%
sql_query = """ SELECT * FROM users WHERE id = 842302 """

# %%
with engine.connect() as conn:
    result  = conn.execute(sql_query)

# %%
print(row)
# Out:
# (0, 842302, 'M', 17.99, 10.38, 122.8, 1001.0, 0.1184, 0.2776, 0.3001, 0.1471, 0.2419, 0.07871, 1.095, 0.9053, 8.589, 153.4, 0.006399, 0.04904, 0.05373, 0.01587, 0.03003, 0.006193, 25.38, 17.33, 184.6, 2019.0, 0.1622, 0.6656, 0.7119, 0.2654, 0.4601, 0.1189, None)

# %%
sql_query2 = """ SELECT * FROM users WHERE radius_mean > 20 """

# %%
with engine.connect() as conn:
    result2 = conn.execute(sql_query2)
    for row in result2:
        print(row)
# Out:
# (1, 842517, 'M', 20.57, 17.77, 132.9, 1326.0, 0.08474, 0.07864, 0.0869, 0.07017, 0.1812, 0.05667, 0.5435, 0.7339, 3.398, 74.08, 0.005225, 0.01308, 0.0186, 0.0134, 0.01389, 0.003532, 24.99, 23.41, 158.8, 1956.0, 0.1238, 0.1866, 0.2416, 0.186, 0.275, 0.08902, None)
# (4, 84358402, 'M', 20.29, 14.34, 135.1, 1297.0, 0.1003, 0.1328, 0.198, 0.1043, 0.1809, 0.05883, 0.7572, 0.7813, 5.438, 94.44, 0.01149, 0.02461, 0.05688, 0.01885, 0.01756, 0.005115, 22.54, 16.67, 152.2, 1575.0, 0.1374, 0.205, 0.4, 0.1625, 0.2364, 0.07678, None)
# (23, 851509, 'M', 21.16, 23.04, 137.2, 1404.0, 0.09428, 0.1022, 0.1097, 0.08632, 0.1769, 0.05278, 0.6917, 1.127, 4.303, 93.99, 0.004728, 0.01259, 0.01715, 0.01038, 0.01083, 0.001987, 29.17, 35.59, 188.0, 2615.0, 0.1401, 0.26, 0.3155, 0.2009, 0.2822, 0.07526, None)
# ...

# %%
sql_query3 = """ SELECT id FROM users
                 ORDER BY perimeter_mean; """

# %%
with engine.connect() as conn:
    result3 = conn.execute(sql_query3)
    for row in result3:
        print(row)
# Out:
# (862722,)
# (862722,)
# (862722,)
# (862722,)
# (92751,)
# (92751,)
# (92751,)
# (92751,)
# (921092,)
# (921092,)
# (921092,)
# (921092,)
# (921362,)
# (921362,)
# (921362,)
# (921362,)
# (85713702,)
# (85713702,)
# (85713702,)
# (85713702,)
# (871001502,)
# (871001502,)
# (871001502,)
# (871001502,)
# (894047,)
# (894047,)
# (894047,)
# (894047,)
# (858477,)
# (858477,)
# (858477,)
# (858477,)
# (872113,)
# (872113,)
# (872113,)
# (872113,)
# (91805,)
# (91805,)
# (91805,)
# (91805,)
# (858981,)
# (858981,)
# (858981,)
# (858981,)
# (903483,)
# (903483,)
# (903483,)
# (903483,)
# (864496,)
# (864496,)
# (864496,)
# (864496,)
# (89346,)
# (89346,)
# (89346,)
# (89346,)
# (9010333,)
# (9010333,)
# (9010333,)
# (9010333,)
# (864726,)
# (864726,)
# (864726,)
# (864726,)
# (859471,)
# (859711,)
# (859471,)
# (859711,)
# (859471,)
# (859711,)
# (859471,)
# (859711,)
# (924342,)
# (924342,)
# (924342,)
# (924342,)
# (859196,)
# (859196,)
# (859196,)
# (859196,)
# (925236,)
# (925236,)
# ...

# %%
sql_query4 = """ SELECT id from users
                 WHERE perimeter_worst > 20 AND perimeter_mean > 30"""

# %%
with engine.connect() as conn:
    result4 = conn.execute(sql_query4)
    for row in result4:
        print(row)
# Out:
# (842302,)
# (842517,)
# (84300903,)
# (84348301,)
# (84358402,)
# (843786,)
# (844359,)
# (84458202,)
# (844981,)
# (84501001,)
# (845636,)
# (84610002,)
# (846226,)
# (846381,)
# (84667401,)
# (84799002,)
# (848406,)
# (84862001,)
# (849014,)
# (8510426,)
# (8510653,)
# (8510824,)
# (8511133,)
# (851509,)
# (852552,)
# (852631,)
# (852763,)
# (852781,)
# (852973,)
# (853201,)
# (853401,)
# (853612,)
# (85382601,)
# (854002,)
# (854039,)
# (854253,)
# (854268,)
# (854941,)
# (855133,)
# (855138,)
# (855167,)
# (855563,)
# (855625,)
# (856106,)
# (85638502,)
# (857010,)
# (85713702,)
# (85715,)
# (857155,)
# (857156,)
# (857343,)
# (857373,)
# (857374,)
# (857392,)
# (857438,)
# (85759902,)
# (857637,)
# (857793,)
# (857810,)
# (858477,)
# (858970,)
# (858981,)
# (858986,)
# (859196,)
# (85922302,)
# (859283,)
# (859464,)
# (859465,)
# (859471,)
# (859487,)
# (859575,)
# (859711,)
# (859717,)
# (859983,)
# (8610175,)
# (8610404,)
# (8610629,)
# (8610637,)
# (8610862,)
# (8610908,)
# ...
